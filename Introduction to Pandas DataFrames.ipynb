# %%
import pandas as pd

# %%
weather_data = { 
'day' : [ '1/1/2017' , '1/2/2017' , '1/3/2017' , '1/4/2017' , '1/5/2017' , '1/6/2017' ], 
'temperature' : [ 32 , 35 , 28 , 24 , 32 , 31 ], 
'windspeed' : [ 6 , 7 , 2 , 7 , 4 , 2 ], 
'event' : [ 'Rain' , 'Sunny' , 'Snow' , 'Snow' , 'Rain' , 'Sunny' ] 
}

# %%
df = pd.DataFrame(weather_data)

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.head(2)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny

# %%
df.tail(4)
# Out:
#         day  temperature  windspeed  event
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.sample(2)
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 0  1/1/2017           32          6   Rain

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df.dtypes
# Out:
# day            object
# temperature     int64
# windspeed       int64
# event          object
# dtype: object

# %%
df.temperature.dtypes
# Out:
# dtype('int64')

# %%
df.set_index('day')
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %% [markdown]
# since set index doesn't change the actual df ... we store the change in other df(named dg)

# %%
dg = df.set_index('day')
dg
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %% [markdown]
# To change the actual df use "inplace"

# %%
df.set_index('day',inplace = True)
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %%
df.reset_index(inplace = True)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %% [markdown]
# index reseted to 0,1,2,3,4...

# %%
df['temperature']
# Out:
# 0    32
# 1    35
# 2    28
# 3    24
# 4    32
# 5    31
# Name: temperature, dtype: int64

# %%
df.temperature
# Out:
# 0    32
# 1    35
# 2    28
# 3    24
# 4    32
# 5    31
# Name: temperature, dtype: int64

# %%
df[['temperature', 'event']]
# Out:
#    temperature  event
# 0           32   Rain
# 1           35  Sunny
# 2           28   Snow
# 3           24   Snow
# 4           32   Rain
# 5           31  Sunny

# %%
df[['temperature', 'event', 'windspeed' ]]
# Out:
#    temperature  event  windspeed
# 0           32   Rain          6
# 1           35  Sunny          7
# 2           28   Snow          2
# 3           24   Snow          7
# 4           32   Rain          4
# 5           31  Sunny          2

# %% [markdown]
# Need to store only two columns then use ...  dg = df.[[...]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          6 non-null      object
#  1   temperature  6 non-null      int64
#  2   windspeed    6 non-null      int64
#  3   event        6 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 320.0+ bytes

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
df[df['temperature']>=32]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 4  1/5/2017           32          4   Rain

# %%
df['event'].value_counts()
# Out:
# Snow     2
# Rain     2
# Sunny    2
# Name: event, dtype: int64

# %%
df.drop('event', axis =1)
# Out:
#         day  temperature  windspeed
# 0  1/1/2017           32          6
# 1  1/2/2017           35          7
# 2  1/3/2017           28          2
# 3  1/4/2017           24          7
# 4  1/5/2017           32          4
# 5  1/6/2017           31          2
